# %%
# importamos las librerias respectivas para el analisis de datos
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

#Importamos el archivo "train.csv"
X=pd.read_csv('./entradas/train.csv')
#Verificamos la lectura del archivo
X.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
Y = X.pop("Survived")
Y.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Survived, dtype: int64

# %%
varNumericas = list(X.dtypes[X.dtypes!="object"].index)
X[varNumericas].head()
# Out:
#    PassengerId  Pclass   Age  SibSp  Parch     Fare
# 0            1       3  22.0      1      0   7.2500
# 1            2       1  38.0      1      0  71.2833
# 2            3       3  26.0      0      0   7.9250
# 3            4       1  35.0      1      0  53.1000
# 4            5       3  35.0      0      0   8.0500

# %%
X["Age"].fillna(X.Age.mean(), inplace=True)
X.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    2.308642   29.699118    0.523008    0.381594   32.204208
# std     257.353842    0.836071   13.002015    1.102743    0.806057   49.693429
# min       1.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%     223.500000    2.000000   22.000000    0.000000    0.000000    7.910400
# 50%     446.000000    3.000000   29.699118    0.000000    0.000000   14.454200
# 75%     668.500000    3.000000   35.000000    1.000000    0.000000   31.000000
# max     891.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
X["Age"].fillna(X.Age.mean(), inplace=True)
X.tail()
# Out:
#      PassengerId  Pclass                                      Name     Sex  \
# 886          887       2                     Montvila, Rev. Juozas    male
# 887          888       1              Graham, Miss. Margaret Edith  female
# 888          889       3  Johnston, Miss. Catherine Helen "Carrie"  female
# 889          890       1                     Behr, Mr. Karl Howell    male
# 890          891       3                       Dooley, Mr. Patrick    male
#
#            Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886  27.000000      0      0      211536  13.00   NaN        S
# 887  19.000000      0      0      112053  30.00   B42        S
# 888  29.699118      1      2  W./C. 6607  23.45   NaN        S
# 889  26.000000      0      0      111369  30.00  C148        C
# 890  32.000000      0      0      370376   7.75   NaN        Q

# %%
X[varNumericas].head()
# Out:
#    PassengerId  Pclass   Age  SibSp  Parch     Fare
# 0            1       3  22.0      1      0   7.2500
# 1            2       1  38.0      1      0  71.2833
# 2            3       3  26.0      0      0   7.9250
# 3            4       1  35.0      1      0  53.1000
# 4            5       3  35.0      0      0   8.0500

# %%
modelo = RandomForestClassifier(n_estimators=100)
modelo.fit(X[varNumericas], Y)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
print "presición ::", accuracy_score(Y, modelo.predict(X[varNumericas]))
# Out:
# presición :: 1.0

# %%
test = pd.read_csv('./entradas/test.csv')
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
test[varNumericas].head()
# Out:
#    PassengerId  Pclass   Age  SibSp  Parch     Fare
# 0          892       3  34.5      0      0   7.8292
# 1          893       3  47.0      1      0   7.0000
# 2          894       2  62.0      0      0   9.6875
# 3          895       3  27.0      0      0   8.6625
# 4          896       3  22.0      1      1  12.2875

# %%
test["Age"].fillna(test.Age.mean(), inplace=True)
test.tail()
# Out:
#      PassengerId  Pclass                          Name     Sex       Age  \
# 413         1305       3            Spector, Mr. Woolf    male  30.27259
# 414         1306       1  Oliva y Ocana, Dona. Fermina  female  39.00000
# 415         1307       3  Saether, Mr. Simon Sivertsen    male  38.50000
# 416         1308       3           Ware, Mr. Frederick    male  30.27259
# 417         1309       3      Peter, Master. Michael J    male  30.27259
#
#      SibSp  Parch              Ticket      Fare Cabin Embarked
# 413      0      0           A.5. 3236    8.0500   NaN        S
# 414      0      0            PC 17758  108.9000  C105        C
# 415      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416      0      0              359309    8.0500   NaN        S
# 417      1      1                2668   22.3583   NaN        C

# %%
test = test[varNumericas].fillna(test.mean()).copy()

# %%
yPrediccion = model.predict(test[varNumericas])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-84907502bb95> in <module>()
# ----> 1 yPrediccion = model.predict(test[varNumericas])
#
# NameError: name 'model' is not defined
